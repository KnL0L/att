# %%
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier

# %%
caminho_arquivo = r'C:\Users\kleberson_belem\Downloads\cliente_compras.xlsx'
df_clientes_compras = pd.read_excel(caminho_arquivo)

# %%
df_clientes_compras
# Out:
#     tempo_gasto_site  numero_itens_visualizados compras_anteriores compra
# 0                 10                          5                Não    Não
# 1                 15                          7                Sim    Sim
# 2                 20                          8                Sim    Sim
# 3                  5                          3                Não    Não
# 4                 25                         10                Sim    Sim
# 5                 30                         12                Sim    Sim
# 6                  8                          4                Não    Não
# 7                 12                          6                Sim    Sim
# 8                 18                          9                Sim    Sim
# 9                  7                          3                Não    Não
# 10                22                         11                Sim    Sim
# 11                28                         13                Sim    Sim
# ...

# %%
caminho_arquivo = r'C:\Users\kleberson_belem\Downloads\clientes_compra_misterio.xlsx'
df_clientes_compras2 = pd.read_excel(caminho_arquivo)

# %%
df_clientes_compras2
# Out:
#     tempo_gasto_site  numero_itens_visualizados compras_anteriores
# 0                 10                          5                Não
# 1                 15                          7                Sim
# 2                 20                          8                Sim
# 3                  5                          3                Não
# 4                 25                         10                Sim
# 5                 30                         12                Sim
# 6                  8                          4                Não
# 7                 12                          6                Sim
# 8                 18                          9                Sim
# 9                  7                          3                Não
# 10                22                         11                Sim
# 11                28                         13                Sim
# 12                 6                          2                Não
# ...

# %%
mapeamento_compras_anteriores = {'Sim': 0, "Não": 1}
mapeamento_compra = {'Sim': 0, "Não": 1}

# %%
df_clientes_compras['compras_anteriores'] = df_clientes_compras['compras_anteriores'].map(mapeamento_compra)

# %%
X = df_clientes_compras[['tempo_gasto_site',	'numero_itens_visualizados',	'compras_anteriores',]]
y = df_clientes_compras['compra']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=37)
modelo = DecisionTreeClassifier()
modelo.fit(X_train, y_train)
previsoes = modelo.predict(X_test)

# %%
df_clientes_compras2['compras_anteriores'] = df_clientes_compras2['compras_anteriores'].map(mapeamento_compra)

# %%
df_clientes_compras2
# Out:
#     tempo_gasto_site  numero_itens_visualizados  compras_anteriores
# 0                 10                          5                   1
# 1                 15                          7                   0
# 2                 20                          8                   0
# 3                  5                          3                   1
# 4                 25                         10                   0
# 5                 30                         12                   0
# 6                  8                          4                   1
# 7                 12                          6                   0
# 8                 18                          9                   0
# 9                  7                          3                   1
# 10                22                         11                   0
# 11                28                         13                   0
# 12                 6                          2                   1
# ...

# %%
previsao = modelo.predict(df_clientes_compras2)

# %%
previsoes
# Out:
# array(['Sim', 'Sim', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Sim', 'Sim',
#        'Sim', 'Sim', 'Sim', 'Sim', 'Não', 'Sim'], dtype=object)
